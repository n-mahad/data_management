# %%
from farmdar.secrets import set_aws_keys
from farmdar.auth import refresh_token
import s3fs
from farmdar.data import insert_df
import dask_geopandas as dgpd
import dask
from dask.distributed import Client
import re
import geopandas as gpd
import pandas as pd
from datetime import datetime
set_aws_keys()

# %%
def get_s3_file_counts_with_s3fs(bucket_name='centralized-data-storage'):
    """
    Count ALL files per client using s3fs (including nested folders in refined)
    
    Structure: s3://bucket/client_name/a_boundaries/refined/**/* (recursive)
    """
    
    # S3 filesystem
    fs = s3fs.S3FileSystem()
    
    # to store results
    client_counts = defaultdict(int)
    client_details = defaultdict(list)
    
    print(f"Scanning bucket: {bucket_name}")
    print("Looking for: client/a_boundaries/refined/ files (including nested folders)")
    print("-" * 60)
    
    try:
        # find all clients
        clients = []
        try:
            bucket_contents = fs.ls(bucket_name)
            clients = [item.split('/')[-1] for item in bucket_contents if fs.isdir(item)]
            print(f"Found {len(clients)} client folders")
        except Exception as e:
            print(f"Error listing clients: {e}")
            return {}
        
        total_files_found = 0
        
        # scan refined folder for every client
        for client in clients:
            client_refined_path = f"{bucket_name}/{client}/a_boundaries/refined"
            
            
            if fs.exists(client_refined_path):
                print(f"Scanning {client}...")
                
                
                pattern = f"{client_refined_path}/**"
                all_items = fs.glob(pattern)
                
                
                files = []
                for item in all_items:
                    if fs.isfile(item):
                        files.append(item)
                
                
                geojson_files = [f for f in files if f.lower().endswith(('.geojson', '.json'))]
                all_files = files  # Saari files count karo, sirf geojson nahi
                
                client_counts[client] = len(all_files)
                
             
                for file_path in all_files[:5]:  # First 5 files ka sample
                    file_name = file_path.split('/')[-1]
                    folder_path = '/'.join(file_path.split('/')[3:])  # Remove bucket/client/a_boundaries
                    client_details[client].append({
                        'file_name': file_name,
                        'relative_path': folder_path,
                        'is_geojson': file_name.lower().endswith(('.geojson', '.json'))
                    })
                
                total_files_found += len(all_files)
                
                if len(all_files) > 0:
                    geojson_count = len(geojson_files)
                    print(f"  {client}: {len(all_files)} total files ({geojson_count} geojson)")
            else:
                print(f"  {client}: No refined folder found")
        
        # Display results
        print("\n" + "="*60)
        print("FINAL RESULTS:")
        print("="*60)
        
        total_clients_with_files = 0
        for client, count in sorted(client_counts.items()):
            if count > 0:
                print(f"{client}: {count} files")
                total_clients_with_files += 1
        
        print("-" * 40)
        print(f"Total Clients with files: {total_clients_with_files}")
        print(f"Total Files: {total_files_found}")
        print("="*60)
        
        return dict(client_counts), dict(client_details)
        
    except Exception as e:
        print(f"Error: {e}")
        return {}, {}

def create_results_dataframe(file_counts, file_details=None):
    """
    Convert results to pandas DataFrame with enhanced details
    """
    if not file_counts:
        return pd.DataFrame()
    
    df_data = []
    for client, count in sorted(file_counts.items()):
        row = {
            'client_name': client, 
            'total_files': count,
            'scan_date': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        }
        
        # Add geojson count if details available
        if file_details and client in file_details:
            geojson_count = sum(1 for f in file_details[client] if f['is_geojson'])
            row['geojson_files'] = geojson_count
            row['other_files'] = count - geojson_count
            
            # Sample file paths
            sample_files = [f['relative_path'] for f in file_details[client][:3]]
            row['sample_files'] = '; '.join(sample_files)
        
        df_data.append(row)
    
    return pd.DataFrame(df_data)

def get_client_details_with_s3fs(client_name, bucket_name='centralized-data-storage'):
    """
    Get detailed file list for a specific client (recursive in refined folder)
    """
    fs = s3fs.S3FileSystem()
    
    try:
        client_path = f"{bucket_name}/{client_name}/a_boundaries/refined"
        
        # Check if path exists
        if not fs.exists(client_path):
            print(f"Path not found: {client_path}")
            return pd.DataFrame()
        
        # Recursive search
        all_items = fs.glob(f"{client_path}/**")
        files = [item for item in all_items if fs.isfile(item)]
        
        file_details = []
        for file_path in files:
            try:
                info = fs.info(file_path)
                file_name = file_path.split('/')[-1]
                
                # Relative path from refined folder
                relative_path = file_path.replace(f"{client_path}/", "")
                folder_depth = len(relative_path.split('/')) - 1
                
                file_details.append({
                    'file_name': file_name,
                    'relative_path': relative_path,
                    'folder_depth': folder_depth,
                    'size_bytes': info.get('size', 0),
                    'size_mb': round(info.get('size', 0) / (1024*1024), 2),
                    'is_geojson': file_name.lower().endswith(('.geojson', '.json')),
                    'last_modified': str(info.get('LastModified', 'N/A'))
                })
            except Exception as file_error:
                print(f"Error processing file {file_path}: {file_error}")
        
        return pd.DataFrame(file_details).sort_values(['folder_depth', 'file_name'])
        
    except Exception as e:
        print(f"Error getting details for {client_name}: {e}")
        return pd.DataFrame()


def analyze_clients():
    """
    Main analysis function with nested folder support
    """
    print("🚀 Starting Client File Analysis (Recursive)")
    print("=" * 60)
    
    # Get file counts and details
    file_counts, file_details = get_s3_file_counts_with_s3fs()
    
    if not file_counts:
        print("❌ No files found or error occurred.")
        return None, None, None
    
    # Create DataFrame with enhanced details
    df = create_results_dataframe(file_counts, file_details)
    
    print(f"\n📊 ANALYSIS COMPLETE")
    print("=" * 60)
    
    return file_counts, file_details, df

# Quick usage examples
def show_top_clients(file_counts, top_n=5):
    """
    Show top N clients by file count
    """
    if not file_counts:
        return
    
    sorted_clients = sorted(file_counts.items(), key=lambda x: x[1], reverse=True)
    
    print(f"\n🔝 TOP {top_n} CLIENTS:")
    for i, (client, count) in enumerate(sorted_clients[:top_n], 1):
        print(f"  {i}. {client}: {count:,} files")

# %%
file_counts, file_details, df = analyze_clients()
# Out:
# 🚀 Starting Client File Analysis (Recursive)
# ============================================================
# Scanning bucket: centralized-data-storage
# Looking for: client/a_boundaries/refined/ files (including nested folders)
# ------------------------------------------------------------
# Found 64 client folders
#   : No refined folder found
#   00_testing: No refined folder found
#   0_Additional_Files: No refined folder found
#   3m_images: No refined folder found
# Scanning ADM...
#   ADM: 8 total files (8 geojson)
# Scanning ASML...
#   ASML: 2 total files (2 geojson)
# Scanning Adam...
#   Adam: 6 total files (6 geojson)
# Scanning Al-Abbas...
#   Al-Abbas: 4 total files (4 geojson)
# Scanning Al-Moiz...
#   Al-Moiz: 31 total files (31 geojson)
# Scanning Alteo...
# Scanning Asia_Poultry_Feeds...
#   Asia_Poultry_Feeds: 4 total files (4 geojson)
# Scanning BAT...
#   BAT: 1 total files (1 geojson)
# Scanning Bank-Alfalah...
#   Bank-Alfalah: 2 total files (2 geojson)
# Scanning Bayer...
# Scanning CFM...
#   CFM: 4 total files (4 geojson)
# Scanning Centrigo...
#   Centrigo: 8 total files (8 geojson)
# Scanning Corteva...
#   Corteva: 104 total files (104 geojson)
# Scanning Demo...
#   Demo: 4 total files (4 geojson)
# Scanning Demo-Farmdar...
#   Demo-Farmdar: 1 total files (1 geojson)
# Scanning FFC...
#   FFC: 4 total files (4 geojson)
# Scanning FFFL...
# Scanning FNC...
#   FNC: 3 total files (3 geojson)
# Scanning FSML...
#   FSML: 10 total files (10 geojson)
# Scanning Faran...
#   Faran: 7 total files (7 geojson)
# Scanning HBSM...
#   HBSM: 7 total files (7 geojson)
# Scanning HSM...
#   HSM: 7 total files (7 geojson)
# Scanning Habib...
# Scanning JAS...
# Scanning JKSM...
#   JKSM: 4 total files (4 geojson)
# Scanning KFM...
#   KFM: 3 total files (3 geojson)
# Scanning KI-Sugar...
#   KI-Sugar: 2 total files (2 geojson)
# Scanning MSF-Sugar...
#   MSF-Sugar: 3 total files (3 geojson)
# Scanning MSML...
#   MSML: 2 total files (2 geojson)
# Scanning Matco...
#   Matco: 2 total files (2 geojson)
# Scanning Matiari...
#   Matiari: 2 total files (2 geojson)
# Scanning Mirpurkhas...
#   Mirpurkhas: 18 total files (17 geojson)
# Scanning Mitrphol...
#   Mitrphol: 2 total files (2 geojson)
# Scanning NFL...
#   NFL: 3 total files (3 geojson)
#   NoneRescaling: No refined folder found
# Scanning Noon...
#   Noon: 9 total files (9 geojson)
# Scanning Omni...
#   Omni: 3 total files (3 geojson)
# Scanning PCCMD...
#   PCCMD: 8 total files (8 geojson)
#   POLARIS: No refined folder found
#   Palm: No refined folder found
#   Pilots: No refined folder found
# Scanning RNSM...
#   RNSM: 6 total files (6 geojson)
# Scanning SQM...
#   SQM: 12 total files (12 geojson)
# Scanning Shah-Murad...
#   Shah-Murad: 2 total files (2 geojson)
# Scanning Sheikhoo...
#   Sheikhoo: 8 total files (8 geojson)
# Scanning Soorty...
# Scanning Syngenta...
# Scanning TRR...
#   TRR: 10 total files (10 geojson)
# Scanning Thaicom...
#   Thaicom: 6 total files (6 geojson)
# Scanning Transmara...
#   Transmara: 5 total files (5 geojson)
# Scanning Unicol...
#   Unicol: 7 total files (7 geojson)
#   agrom_ai: No refined folder found
#   amadeus: No refined folder found
# Scanning chashma...
#   chashma: 2 total files (2 geojson)
#   delivery_tiffs_clipped_mosaicked: No refined folder found
#   farmdar_data_catalog: No refined folder found
#   msfsugar: No refined folder found
#   processed_tiffs: No refined folder found
#   s3:: No refined folder found
#   zarr: No refined folder found
#
# ============================================================
# FINAL RESULTS:
# ============================================================
# ADM: 8 files
# ASML: 2 files
# Adam: 6 files
# Al-Abbas: 4 files
# Al-Moiz: 31 files
# Asia_Poultry_Feeds: 4 files
# BAT: 1 files
# Bank-Alfalah: 2 files
# CFM: 4 files
# Centrigo: 8 files
# Corteva: 104 files
# Demo: 4 files
# Demo-Farmdar: 1 files
# FFC: 4 files
# FNC: 3 files
# FSML: 10 files
# Faran: 7 files
# HBSM: 7 files
# HSM: 7 files
# JKSM: 4 files
# KFM: 3 files
# KI-Sugar: 2 files
# MSF-Sugar: 3 files
# MSML: 2 files
# Matco: 2 files
# Matiari: 2 files
# Mirpurkhas: 18 files
# Mitrphol: 2 files
# NFL: 3 files
# Noon: 9 files
# Omni: 3 files
# PCCMD: 8 files
# RNSM: 6 files
# SQM: 12 files
# Shah-Murad: 2 files
# Sheikhoo: 8 files
# TRR: 10 files
# Thaicom: 6 files
# Transmara: 5 files
# Unicol: 7 files
# chashma: 2 files
# ----------------------------------------
# Total Clients with files: 41
# Total Files: 336
# ============================================================
#
# 📊 ANALYSIS COMPLETE
# ============================================================

# %%
show_top_clients(file_counts)
# Out:
# 🔝 TOP 5 CLIENTS:
#   1. Corteva: 104 files
#   2. Al-Moiz: 31 files
#   3. Mirpurkhas: 18 files
#   4. SQM: 12 files
#   5. FSML: 10 files

# %%
client_df = get_client_details_with_s3fs("Mirpurkhas")
display(client_df)
# Out:
#                                             file_name  \
# 0   Crop-Scan_Canola_10m_2024_2025-02-01_Mirpurkha...
# 1   Crop-Scan_Canola_10m_2024_2025-02-01_Mirpurkha...
# 2   Crop-Scan_Canola_10m_2024_2025-02-01_Mirpurkha...
# 3   Crop-Scan_Sugarcane_10m_2023_2023-11-04_Mirpur...
# 4   Crop-Scan_Sugarcane_10m_2023_2023-11-04_Mirpur...
# 5   Crop-Scan_Sugarcane_3m-10m_2023_2023-10-09_Mir...
# 6   Crop-Scan_Sugarcane_3m-10m_2023_2023-10-09_Mir...
# 7   Crop-Scan_Sugarcane_3m-10m_2023_2023-10-09_Mir...
# 8   Crop-Scan_Sugarcane_3m_2023_2023-10-09_Mirpurk...
# 9   Crop-Scan_Sugarcane_3m_2023_2023-10-09_Mirpurk...
# 10  Crop-Scan_Sugarcane_3m_2023_2023-10-09_Mirpurk...
# 11  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...
# 12  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...
# 13  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...
# 14  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...
# 15  Variety-Scan_Sugarcane_3m_2023_2023-10-09_Mirp...
# 16  Variety-Scan_Sugarcane_3m_2023_2023-10-09_Mirp...
# 17  Variety-Scan_Sugarcane_3m_2023_2023-10-09_Mirp...
#
#                                         relative_path  folder_depth  \
# 0   Crop-Scan_Canola_10m_2024_2025-02-01_Mirpurkha...             0
# 1   Crop-Scan_Canola_10m_2024_2025-02-01_Mirpurkha...             0
# 2   Crop-Scan_Canola_10m_2024_2025-02-01_Mirpurkha...             0
# 3   Crop-Scan_Sugarcane_10m_2023_2023-11-04_Mirpur...             0
# 4   Crop-Scan_Sugarcane_10m_2023_2023-11-04_Mirpur...             0
# 5   Crop-Scan_Sugarcane_3m-10m_2023_2023-10-09_Mir...             0
# 6   Crop-Scan_Sugarcane_3m-10m_2023_2023-10-09_Mir...             0
# 7   Crop-Scan_Sugarcane_3m-10m_2023_2023-10-09_Mir...             0
# 8   Crop-Scan_Sugarcane_3m_2023_2023-10-09_Mirpurk...             0
# 9   Crop-Scan_Sugarcane_3m_2023_2023-10-09_Mirpurk...             0
# 10  Crop-Scan_Sugarcane_3m_2023_2023-10-09_Mirpurk...             0
# 11  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...             0
# 12  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...             0
# 13  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...             0
# 14  Crop-Scan_Sugarcane_3m_2024_2024-09-09_Mirpurk...             0
# 15  Variety-Scan_Sugarcane_3m_2023_2023-10-09_Mirp...             0
# 16  Variety-Scan_Sugarcane_3m_2023_2023-10-09_Mirp...             0
# 17  Variety-Scan_Sugarcane_3m_2023_2023-10-09_Mirp...             0
#
#     size_bytes  size_mb  is_geojson              last_modified
# 0       112681     0.11        True  2025-02-27 07:20:07+00:00
# 1       166009     0.16        True  2025-03-03 08:49:56+00:00
# 2       388721     0.37        True  2025-02-27 07:20:08+00:00
# 3        99677     0.10        True  2024-11-24 14:46:08+00:00
# 4       270728     0.26        True  2024-11-24 14:46:08+00:00
# 5        79479     0.08        True  2024-11-24 14:46:13+00:00
# 6       178144     0.17        True  2024-11-24 14:46:07+00:00
# 7       651954     0.62        True  2024-11-24 14:46:07+00:00
# 8       147150     0.14        True  2024-11-24 14:46:10+00:00
# 9       178140     0.17        True  2024-11-24 14:46:11+00:00
# 10      343054     0.33        True  2024-11-24 14:46:11+00:00
# 11      151423     0.14        True  2024-11-24 14:46:12+00:00
# 12      182710     0.17        True  2024-11-24 14:46:12+00:00
# 13       53020     0.05       False  2025-05-02 11:09:59+00:00
# 14      347687     0.33        True  2024-11-24 14:46:13+00:00
# 15      147153     0.14        True  2024-11-24 14:46:09+00:00
# 16      178143     0.17        True  2024-11-24 14:46:09+00:00
# 17      343057     0.33        True  2024-11-24 14:46:10+00:00
